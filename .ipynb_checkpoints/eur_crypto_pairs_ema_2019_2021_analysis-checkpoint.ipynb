# %%
import pandas as pd
import numpy as np
from os import listdir
from os.path import isfile, join

# %%
DIR_PATH = "eur_pairs/"
FILES = [f for f in listdir(dir_path)]
OUTPUTS = []

# %%
def col_total(df):
    return df[df.columns[0]].count()

def output_gen(df, output_list):
    return output_list.append(df.name), output_list.append({df.name + "_len": col_total(df)}), output_list.append({df.name + "_chg": df["chg%"].sum()}), output_list.append({df.name + "_mean": df["chg%"].mean()})

# %%
for current_file in FILES:
    # create df
    df = pd.read_csv(DIR_PATH + current_file, parse_dates=True)
    df.name = current_file
    df.index = df["Date"]
    df.drop(["Date"],axis=1,inplace=True)
    
    # add calculations
    df["sma9"] = df["Close"].rolling(9).mean()
    df["sma20"] = df["Close"].rolling(20).mean()
    df["sma50"] = df["Close"].rolling(50).mean()
    df["chg%"] = (df["Close"] / df["Close"].shift(1)) - 1
    
    # get data set as list of dicts and append to output
    output = []
    output.append(current_file)
    # main
    output.append({"total_len": col_total(df)})
    output.append({"total_chg": df["chg%"].sum()})
    output.append({"total_mean": df["chg%"].mean()})
    # abv 9 abv 20 abv 50
    abv9_abv20_abv50 = df[(df["Close"] > df["sma9"]) & (df["Close"] > df["sma20"]) & (df["Close"] > df["sma50"])]
    abv9_abv20_abv50.name = "abv9_abv20_abv50"
    output_gen(abv9_abv20_abv50, output)
    # abv 9 abv 20 blw 50
    abv9_abv20_blw50 = df[(df["Close"] > df["sma9"]) & (df["Close"] > df["sma20"]) & (df["Close"] < df["sma50"])]
    abv9_abv20_blw50.name = "abv9_abv20_blw50"
    output_gen(abv9_abv20_blw50, output)
    # abv 9 blw 20 blw 50
    abv9_blw20_blw50 = df[(df["Close"] > df["sma9"]) & (df["Close"] < df["sma20"]) & (df["Close"] < df["sma50"])]
    abv9_blw20_blw50.name = "abv9_blw20_blw50"
    output_gen(abv9_blw20_blw50, output)
    # abv 9 blw 20 abv 50
    abv9_blw20_abv50 = df[(df["Close"] > df["sma9"]) & (df["Close"] < df["sma20"]) & (df["Close"] > df["sma50"])]
    abv9_blw20_abv50.name = "abv9_blw20_abv50"
    output_gen(abv9_blw20_abv50, output)
    # blw 9 blw 20 abv 50
    blw9_blw20_abv50 = df[(df["Close"] < df["sma9"]) & (df["Close"] < df["sma20"]) & (df["Close"] > df["sma50"])]
    blw9_blw20_abv50.name = "blw9_blw20_abv50"
    output_gen(blw9_blw20_abv50, output)
    # blw 9 abv 20 abv 50
    blw9_abv20_abv50 = df[(df["Close"] < df["sma9"]) & (df["Close"] > df["sma20"]) & (df["Close"] > df["sma50"])]
    blw9_abv20_abv50.name = "blw9_abv20_abv50"
    output_gen(blw9_abv20_abv50, output)
    # blw 9 abv 20 blw 50
    blw9_abv20_blw50 = df[(df["Close"] < df["sma9"]) & (df["Close"] > df["sma20"]) & (df["Close"] < df["sma50"])]
    blw9_abv20_blw50.name = "blw9_abv20_blw50"
    output_gen(blw9_abv50_blw50, output)
    # blw 9 blw 20 blw 50
    blw9_blw20_blw50 = df[(df["Close"] < df["sma9"]) & (df["Close"] < df["sma20"]) & (df["Close"] < df["sma50"])]
    blw9_blw20_blw50.name = "blw9_blw20_blw50"
    output_gen(blw9_blw50_blw50, output)
    OUTPUTS.append(output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-104-0a8e7dcdd1b9> in <module>
#      42     blw9_abv20_abv50 = df[(df["Close"] < df["sma9"]) & (df["Close"] > df["sma20"]) & (df["Close"] > df["sma50"])]
#      43     blw9_abv20_abv50.name = "blw9_abv20_abv50"
# ---> 44     output_gen(blw9_abv50_abv50, output)
#      45     # blw 9 abv 20 blw 50
#      46     blw9_abv20_blw50 = df[(df["Close"] < df["sma9"]) & (df["Close"] > df["sma20"]) & (df["Close"] < df["sma50"])]
#
# NameError: name 'blw9_abv50_abv50' is not defined

# %%
OUTPUTS
# Out:
# [['ADA-EUR.csv',
#   {'total_len': 554},
#   {'total_chg': 3.916764434948537},
#   {'total_mean': 0.007121389881724618},
#   {'abv50_abv200_len': 212},
#   {'abv50_abv200_chg': 4.302051031743071},
#   {'abv50_abv200_mean': 0.020292693545957897},
#   {'abv50_blw200_len': 45},
#   {'abv50_blw200_chg': -0.6239697250226954},
#   {'abv50_blw200_mean': -0.013865993889393231},
#   {'blw50_abv200_len': 35},
#   {'blw50_abv200_chg': 0.4937777734210179},
#   {'blw50_abv200_mean': 0.014107936383457654},
#   {'blw50_blw200_len': 113},
#   {'blw50_blw200_chg': -1.435173245225542},
#   {'blw50_blw200_mean': -0.012700648187836653}],
#  ['AVAX-EUR.csv',
#   {'total_len': 183},
#   {'total_chg': 2.578810444163442},
#   {'total_mean': 0.014487699124513724},
#   {'abv50_abv200_len': 64},
#   {'abv50_abv200_chg': 3.338742839770327},
#   {'abv50_abv200_mean': 0.05216785687141136},
#   {'abv50_blw200_len': 15},
#   {'abv50_blw200_chg': -0.2765801755901378},
#   {'abv50_blw200_mean': -0.018438678372675855},
#   {'blw50_abv200_len': 2},
#   {'blw50_abv200_chg': 0.0033505868025185404},
#   {'blw50_abv200_mean': 0.0016752934012592702},
#   {'blw50_blw200_len': 36},
#   {'blw50_blw200_chg': -0.25216565385600287},
#   {'blw50_blw200_mean': -0.00700460149600008}],
#  ['BCH-EUR.csv',
#   {'total_len': 554},
#   {'total_chg': 1.1449018386579883},
#   {'total_mean': 0.0020816397066508873},
#   {'abv50_abv200_len': 153},
#   {'abv50_abv200_chg': 2.8701243146738964},
#   {'abv50_abv200_mean': 0.018758982448848997},
#   {'abv50_blw200_len': 48},
#   {'abv50_blw200_chg': -0.4730271862057617},
#   {'abv50_blw200_mean': -0.009854733045953369},
#   {'blw50_abv200_len': 38},
#   {'blw50_abv200_chg': 0.29619394796665166},
#   {'blw50_abv200_mean': 0.007794577578069781},
#   {'blw50_blw200_len': 166},
#   {'blw50_blw200_chg': -1.7231930892481844},
#   {'blw50_blw200_mean': -0.010380681260531235}],
#  ['BNB-EUR.csv',
#   {'total_len': 554},
#   {'total_chg': 3.3074435578392354},
#   {'total_mean': 0.006013533741525882},
#   {'abv50_abv200_len': 233},
#   {'abv50_abv200_chg': 4.4410981539577925},
#   {'abv50_abv200_mean': 0.0190605070985313},
#   {'abv50_blw200_len': 33},
#   {'abv50_blw200_chg': -0.22400479253619654},
#   {'abv50_blw200_mean': -0.00678802401624838},
#   {'blw50_abv200_len': 26},
#   {'blw50_abv200_chg': 0.4123897840746197},
#   {'blw50_abv200_mean': 0.015861145541331525},
#   {'blw50_blw200_len': 113},
#   {'blw50_blw200_chg': -1.323996611297311},
#   {'blw50_blw200_mean': -0.011716784170772663}],
#  ['BTC-EUR.csv',
#   {'total_len': 554},
#   {'total_chg': 2.013701477196796},
#   {'total_mean': 0.0036612754130850847},
#   {'abv50_abv200_len': 171},
#   {'abv50_abv200_chg': 2.3461514749260903},
#   {'abv50_abv200_mean': 0.01372018406389526},
#   {'abv50_blw200_len': 58},
#   {'abv50_blw200_chg': -0.5209196965489405},
#   {'abv50_blw200_mean': -0.00898137407843001},
#   {'blw50_abv200_len': 55},
#   {'blw50_abv200_chg': 0.346503864143617},
#   {'blw50_abv200_mean': 0.006300070257156673},
#   {'blw50_blw200_len': 121},
#   {'blw50_blw200_chg': -0.8841903459197906},
#   {'blw50_blw200_mean': -0.007307358230742071}],
#  ['DOGE-EUR.csv',
#   {'total_len': 554},
#   {'total_chg': 5.774914235337352},
#   {'total_mean': 0.010499844064249732},
#   {'abv50_abv200_len': 157},
#   {'abv50_abv200_chg': 6.772537942186919},
#   {'abv50_abv200_mean': 0.043137184345139634},
#   {'abv50_blw200_len': 70},
#   {'abv50_blw200_chg': -0.7151195408193726},
#   {'abv50_blw200_mean': -0.01021599344027675},
#   {'blw50_abv200_len': 19},
#   {'blw50_abv200_chg': 0.2601454011221419},
#   {'blw50_abv200_mean': 0.013691863216954836},
#   {'blw50_blw200_len': 159},
#   {'blw50_blw200_chg': -1.0105849564374172},
#   {'blw50_blw200_mean': -0.006355880229166145}],
#  ['EGLD-EUR.csv',
#   {'total_len': 186},
#   {'total_chg': 3.570025562739726},
#   {'total_mean': 0.01950833640841379},
#   {'abv50_abv200_len': 105},
#   {'abv50_abv200_chg': 3.5308874888770614},
#   {'abv50_abv200_mean': 0.03362749989406724},
#   {'abv50_blw200_len': 18},
#   {'abv50_blw200_chg': -0.04830753833561341},
#   {'abv50_blw200_mean': -0.0026837521297563005},
#   {'blw50_abv200_len': 0},
#   {'blw50_abv200_chg': 0.0},
#   {'blw50_abv200_mean': nan},
#   {'blw50_blw200_len': 3},
#   {'blw50_blw200_chg': -0.08444211724116935},
#   {'blw50_blw200_mean': -0.028147372413723115}],
#  ['EOS-EUR.csv',
#   {'total_len': 554},
#   {'total_chg': 0.7116389241989576},
#   {'total_mean': 0.0012938889530890137},
#   {'abv50_abv200_len': 148},
#   {'abv50_abv200_chg': 2.2417895984015273},
#   {'abv50_abv200_mean': 0.015147227016226544},
#   {'abv50_blw200_len': 45},
#   {'abv50_blw200_chg': -0.498376281967182},
#   {'abv50_blw200_mean': -0.0110750284881596},
#   {'blw50_abv200_len': 41},
#   {'blw50_abv200_chg': 0.43530521878978023},
#   {'blw50_abv200_mean': 0.010617200458287323},
#   {'blw50_blw200_len': 171},
#   {'blw50_blw200_chg': -1.5985539932340465},
#   {'blw50_blw200_mean': -0.009348268966280973}],
#  ['ETH-EUR.csv',
#   {'total_len': 554},
#   {'total_chg': 2.579285181471183},
#   {'total_mean': 0.004689609420856693},
#   {'abv50_abv200_len': 203},
#   {'abv50_abv200_chg': 3.5594482858346073},
#   {'abv50_abv200_mean': 0.017534228009037464},
#   {'abv50_blw200_len': 56},
#   {'abv50_blw200_chg': -0.6460233001473878},
#   {'abv50_blw200_mean': -0.011536130359774783},
#   {'blw50_abv200_len': 27},
#   {'blw50_abv200_chg': 0.3790755040603816},
#   {'blw50_abv200_mean': 0.014039833483717836},
#   {'blw50_blw200_len': 119},
#   {'blw50_blw200_chg': -1.3526380573294507},
#   {'blw50_blw200_mean': -0.011366706364113032}],
#  ['LINK-EUR.csv',
#   {'total_len': 554},
#   {'total_chg': 3.5968997081017346},
#   {'total_mean': 0.006539817651094064},
#   {'abv50_abv200_len': 211},
#   {'abv50_abv200_chg': 4.228732006776427},
#   {'abv50_abv200_mean': 0.020041383918371677},
#   {'abv50_blw200_len': 51},
#   {'abv50_blw200_chg': -0.16430984299331652},
#   {'abv50_blw200_mean': -0.0032217616273199317},
#   {'blw50_abv200_len': 14},
#   {'blw50_abv200_chg': 0.4911998650642614},
#   {'blw50_abv200_mean': 0.035085704647447244},
#   {'blw50_blw200_len': 129},
#   {'blw50_blw200_chg': -1.791984482819062},
#   {'blw50_blw200_mean': -0.01389135257999273}],
#  ['LTC-EUR.csv',
#   {'total_len': 554},
#   {'total_chg': 1.4623386098429862},
#   {'total_mean': 0.002658797472441795},
#   {'abv50_abv200_len': 165},
#   {'abv50_abv200_chg': 3.015460318538268},
#   {'abv50_abv200_mean': 0.018275517082050104},
#   {'abv50_blw200_len': 52},
#   {'abv50_blw200_chg': -0.9587586125042735},
#   {'abv50_blw200_mean': -0.018437665625082186},
#   {'blw50_abv200_len': 34},
#   {'blw50_abv200_chg': 0.40434829970446684},
#   {'blw50_abv200_mean': 0.011892597050131378},
#   {'blw50_blw200_len': 154},
#   {'blw50_blw200_chg': -1.4983987188888719},
#   {'blw50_blw200_mean': -0.009729861810966698}],
#  ['XLM-EUR.csv',
#   {'total_len': 554},
#   {'total_chg': 2.565923823538353},
#   {'total_mean': 0.004665316042797009},
#   {'abv50_abv200_len': 152},
#   {'abv50_abv200_chg': 2.956808538406197},
#   {'abv50_abv200_mean': 0.01945268775267236},
#   {'abv50_blw200_len': 61},
#   {'abv50_blw200_chg': -0.612791147426719},
#   {'abv50_blw200_mean': -0.010045756515192116},
#   {'blw50_abv200_len': 23},
#   {'blw50_abv200_chg': 0.41290985976367334},
#   {'blw50_abv200_mean': 0.01795260259842058},
#   {'blw50_blw200_len': 169},
#   {'blw50_blw200_chg': -1.7665558658403508},
#   {'blw50_blw200_mean': -0.010452993288996163}],
#  ['XRP-EUR.csv',
#   {'total_len': 554},
#   {'total_chg': 1.5528185366072034},
#   {'total_mean': 0.002823306430194915},
#   {'abv50_abv200_len': 134},
#   {'abv50_abv200_chg': 2.5192266617171852},
#   {'abv50_abv200_mean': 0.01880019896803871},
#   {'abv50_blw200_len': 51},
#   {'abv50_blw200_chg': -0.7668431586089529},
#   {'abv50_blw200_mean': -0.015036140364881429},
#   {'blw50_abv200_len': 54},
#   {'blw50_abv200_chg': 0.6044346479593021},
#   {'blw50_abv200_mean': 0.011193234221468559},
#   {'blw50_blw200_len': 166},
#   {'blw50_blw200_chg': -1.871287161505652},
#   {'blw50_blw200_mean': -0.011272814225937665}]]

# %%
# Out:
#                 Open      High       Low     Close  Adj Close        Volume  \
# Date
# 2019-09-18  0.044199  0.049796  0.044305  0.048318   0.048318  1.253522e+08
# 2019-09-19  0.048322  0.049436  0.045175  0.047526   0.047526  1.170993e+08
# 2019-09-20  0.047514  0.047694  0.045845  0.047497   0.047497  8.759988e+07
# 2019-09-21  0.047492  0.048411  0.046596  0.047117   0.047117  7.437985e+07
# 2019-09-22  0.047092  0.047148  0.043430  0.044569   0.044569  7.818356e+07
# ...              ...       ...       ...       ...        ...           ...
# 2021-03-24  0.947042  0.983395  0.894601  0.910035   0.910035  3.182395e+09
# 2021-03-25  0.909581  0.979103  0.893302  0.935460   0.935460  4.868225e+09
# 2021-03-26  0.935333  1.086292  0.933237  1.029292   1.029292  5.363472e+09
# 2021-03-27  1.029387  1.048206  0.986203  0.997588   0.997588  2.634232e+09
# 2021-03-28  1.012448  1.029089  0.991413  1.007459   1.007459  2.175552e+09
#
#                50ema  200ema      chg%
# Date
# 2019-09-18       NaN     NaN       NaN
# 2019-09-19       NaN     NaN -0.016391
# 2019-09-20       NaN     NaN -0.000610
# 2019-09-21       NaN     NaN -0.008001
# 2019-09-22       NaN     NaN -0.054078
# ...              ...     ...       ...
# 2021-03-24  0.854654     NaN -0.039254
# 2021-03-25  0.866031     NaN  0.027938
# 2021-03-26  0.879246     NaN  0.100306
# 2021-03-27  0.890269     NaN -0.030802
# 2021-03-28  0.899996     NaN  0.009895
#
# [558 rows x 9 columns]

# %%
abv50_abv200 = df[(df["Close"] > df["ema50"]) & (df["Close"] > df["ema200"])]
    output.append({"abv50_abv200_len": col_total(abv50_abv200)})
    output.append({"abv50_abv200_chg": abv50_abv200["chg%"].sum()})
    output.append({"abv50_abv200_mean": abv50_abv200["chg%"].mean()})
    # abv 50 blw 200
    abv50_blw200 = df[(df["Close"] > df["ema50"]) & (df["Close"] < df["ema200"])]
    output.append({"abv50_blw200_len": col_total(abv50_blw200)})
    output.append({"abv50_blw200_chg": abv50_blw200["chg%"].sum()})
    output.append({"abv50_blw200_mean": abv50_blw200["chg%"].mean()})
    # blw 50 abv 200
    blw50_abv200 = df[(df["Close"] < df["ema50"]) & (df["Close"] > df["ema200"])]
    output.append({"blw50_abv200_len": col_total(blw50_abv200)})
    output.append({"blw50_abv200_chg": blw50_abv200["chg%"].sum()})
    output.append({"blw50_abv200_mean": blw50_abv200["chg%"].mean()})
    # blw 50 blw 200
    blw50_blw200 = df[(df["Close"] < df["ema50"]) & (df["Close"] < df["ema200"])]
    output.append({"blw50_blw200_len": col_total(blw50_blw200)})
    output.append({"blw50_blw200_chg": blw50_blw200["chg%"].sum()})
    output.append({"blw50_blw200_mean": blw50_blw200["chg%"].mean()})
    # append to global
